# %% [markdown]
# ## 1. Data loading and overview

# %%
import pandas as pd

df = pd.DataFrame()  # Replace with actual dataset load path
df.head()

# %% [markdown]
# ## 2. Summary statistics and missing values

# %%
# df.describe(include='all')
# df.isna().sum()

# %% [markdown]
# ## 3. Top insights
#
# 1. Insight 1: ...
# 2. Insight 2: ...
# 3. Insight 3: ...
